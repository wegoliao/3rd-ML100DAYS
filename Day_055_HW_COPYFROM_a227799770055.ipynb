# %% [markdown]
# # 作業
#
# - 作業目標 : iris (dataset.load_iris()) 資料嘗試跑 kmeans (可以測試不同的群數 , init 等)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets

np.random.seed(5)

# %matplotlib inline
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### 載入 相關套件 並 執行 kmean 實驗 ...
#
# - 實驗測試不同的群數
# - 實驗測試不同的初始值
# - 呈現結果

# %%
estimators = [('k_means_8', KMeans(n_clusters=8)),
              ('k_means_3', KMeans(n_clusters=3)),
              ('k_means_bad_init', KMeans(n_clusters=3, n_init=1,
                                               init='random'))]

# %%
#n_clusters=3
kmean=KMeans(n_clusters=3)
kmean.fit(iris.data)
label=kmean.labels_
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(iris.data[:,2],iris.data[:,0],iris.data[:,3],c=label,edgecolor='k')
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
plt.title('n_clusters=3')
# Out:
# Text(0.5, 0.92, 'n_clusters=3')

# %%
#n_clusters=5
kmean=KMeans(n_clusters=5)
kmean.fit(iris.data)
label=kmean.labels_
fig=plt.figure()
ax=Axes3D(fig)
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.scatter(iris.data[:,2],iris.data[:,0],iris.data[:,3],c=label,edgecolor='k')
plt.title('n_clusters=5')
# Out:
# Text(0.5, 0.92, 'n_clusters=5')

# %%
#real data
fig=plt.figure()
ax=Axes3D(fig)
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.scatter(iris.data[:,2],iris.data[:,0],iris.data[:,3],c=iris.target,edgecolor='k')
plt.title('real data')
# Out:
# Text(0.5, 0.92, 'real data')
